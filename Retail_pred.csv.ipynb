# %%
import os

os.listdir()
# Out:
# ['DataSetRetail.csv',
#  'submission format.csv',
#  'Retail_pred.csv.ipynb',
#  'Traindata.csv',
#  '.ipynb_checkpoints']

# %%
import pandas as pd
import seaborn as sns

# %%
train_df = pd.read_csv("/Users/sreevaatsav/Downloads/IOT/Traindata.csv")
test_df = pd.read_csv("/Users/sreevaatsav/Downloads/IOT/DataSetRetail.csv")

# %%
train_df
# Out:
#         record_ID        week  store_id  sku_id  total_price  base_price  \
# 0               1  17-01-2011      8091  216418      99.0375    111.8625
# 1               2  17-01-2011      8091  216419      99.0375     99.0375
# 2               3  17-01-2011      8091  216425     133.9500    133.9500
# 3               4  17-01-2011      8091  216233     133.9500    133.9500
# 4               5  17-01-2011      8091  217390     141.0750    141.0750
# ...           ...         ...       ...     ...          ...         ...
# 150145     212638  09-07-2013      9984  223245     235.8375    235.8375
# 150146     212639  09-07-2013      9984  223153     235.8375    235.8375
# 150147     212642  09-07-2013      9984  245338     357.6750    483.7875
# 150148     212643  09-07-2013      9984  547934     141.7875    191.6625
# 150149     212644  09-07-2013      9984  679023     234.4125    234.4125
#
#         is_featured_sku  is_display_sku  units_sold
# ...
